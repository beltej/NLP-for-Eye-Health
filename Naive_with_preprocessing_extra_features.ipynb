# %%
import pandas as pd
import numpy as np
import spacy
sp = spacy.load('en_core_web_sm',disable=['parser', 'ner'])    ### import English core language model from spaCy
# sp = spacy.load('en')

# %%
# import sys
# !conda install --yes --prefix {sys.prefix} spacy

###### did not work

# !conda install --yes --prefix {sys.prefix} textblob 
# !conda install --yes --prefix {sys.prefix} -c https://conda.anaconda.org/sloria textblob
# python -m textblob.download_corpora


#### worked from command line 
# conda install -c conda-forge textblob

# %%
##### to print multiple outputs from same cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
file_path = "/Users/tejasvibelsare/Documents/New_gold.xlsx"
train = pd.read_excel(file_path, sheet_name='Sheet1',usecols = "B,H")

# %%
##### information about dataset

len(train)                  ### length of training data
train.columns               #### get columns from data
train.category.value_counts()   #### get category wise count
train.head()           #### get top records from data
train.isnull().sum(axis = 0)   ### get null records
train.describe()
# Out:
# 86
# Index(['Contents', 'category'], dtype='object')
# allergic      45
# infectious    41
# Name: category, dtype: int64
#                                             Contents    category
# 0              My allergies killin my widdle eyes ??    allergic
# 1    Well think I woke up today with pink eye smh...  infectious
# 2  Seriously fuck allergies my eyes hurt and itch...    allergic
# 3                           My eye itchin #allergies    allergic
# 4  November was hand foot and mouth. December is ...  infectious
# Contents    0
# category    0
# dtype: int64
#                                         Contents  category
# count                                         86        86
# unique                                        86         2
# top     My eyes itching so bad ?? damn allergies  allergic
# freq                                           1        45

# %%
from nltk.stem import WordNetLemmatizer  
# nltk.download('wordnet')   ### to download wordnet. It was giving error without downloading
  
def lemmatize_tweets(each_tweet):
#     print(each_tweet)
    lemmatizer = WordNetLemmatizer()  
    words = each_tweet.split(" ")
    
    preprocessed_text = " ".join([lemmatizer.lemmatize(word) for word in words])
#     print(preprocessed_text)
    return preprocessed_text

# sentence = "My allergies have my eyes itching something crazy"

# sentence = lemmatize_tweets(sentence)
# # print(sentence)

# %%
def remove_usernames(each_tweet):

    usernames_removed_tweet = re.sub(r'@[A-Za-z0-9]+', '', each_tweet)
    return usernames_removed_tweet

# %%
def remove_url(each_tweet):

    url_removed_tweets = re.sub('https?://[A-Za-z0-9./]+', '', each_tweet)
    return url_removed_tweets

# %%
def remove_dots(each_tweet):
    dots = re.compile(r'\.{3,}')
    removed_dots_word = dots.sub('', each_tweet)
    return removed_dots_word

# %%
def remove_punctuation(each_tweet):
#     punctuations = "?:!.,;#=()/"
#     punctuation_removed_tweets = re.sub("?:!.,;#=()/ ", '', each_tweet)
    punctuation_removed_tweets = re.sub('[%s]' % re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), '', each_tweet)
    return punctuation_removed_tweets

# %%
from textblob import TextBlob

def calculate_sentiment(tweet):
#     tweet = read_df['Contents'][i]
    tweet = TextBlob(tweet)
    pol = tweet.sentiment.polarity
    sub = tweet.sentiment.subjectivity
    return pol, sub

# print(train.Contents)

# %%
def get_tweet_length(tweet):
    return len(tweet)

# %%
def number_of_words_in_tweet(tweet):
    count = len(tweet.split())
    return count

# %%
import re
# idx = pd.IndexSlice
# sentiment = pd.DataFrame()

def preprocess(data):
#     data.reset_index(drop=True, inplace=True)

    for index, row in data.iterrows():
        each_tweet = str(row["Contents"])
        
        polarity, subjectivity = calculate_sentiment(each_tweet)
#         data.at[index,'polarity'] = polarity
#         print(polarity)
#         print(subjectivity)
#         data.at[index,'subjectivity'] = subjectivity
        data.loc[index,'polarity'] = polarity
        data.loc[index,'subjectivity'] = subjectivity
        
        length = get_tweet_length(each_tweet)
        data.loc[index,'tweet_length'] = length
        
        words = number_of_words_in_tweet(each_tweet)
        data.loc[index,'no_of_words'] = words
        
#         data.loc[idx[index,:], 'polarity'] = polarity

        
        url_removed_tweets = remove_url(each_tweet)
        
        usernames_removed_tweet = remove_usernames(url_removed_tweets)
        
        punctuation_removed_tweets = remove_punctuation(usernames_removed_tweet)
        
        numbers_removed_tweets = punctuation_removed_tweets.replace('\d+', '')
        
        removed_dots_word = remove_dots(numbers_removed_tweets)
        
        if type(removed_dots_word) is str:
            lower_case_tweet = removed_dots_word.lower()
            
#         punctuation_removed_tweets = remove_punctuation(lower_case_tweet)
        
#         removed_dots_word = remove_dots(punctuation_removed_tweets)
        
#         url_removed_tweets = remove_url(removed_dots_word)
        
#         usernames_removed_tweet = remove_usernames(url_removed_tweets)

        lemmatized_tweet= lemmatize_tweets(lower_case_tweet)
        data.at[index,'Contents'] = lemmatized_tweet
        
#         print(data.head)

    return data

# %%
from sklearn import preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer

print(type(train))
train.reset_index(drop=True, inplace=True)
train = preprocess(train)
# print(train)

encode = preprocessing.LabelEncoder()
# train['category'] = encode.fit_transform(train['category'])
train['category'] = encode.fit_transform(train['category'])

tfidf = TfidfVectorizer(min_df=2,stop_words='english')

traintf = tfidf.fit_transform(train.Contents)
# print(traintf)

train_df = pd.DataFrame(traintf.todense())
train_df.columns = tfidf.get_feature_names()


sentiment = pd.DataFrame(train[['polarity','subjectivity','tweet_length','no_of_words']])
# df1 = df[['a','b']]
train_df = pd.concat([train_df,sentiment], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# encode.inverse_transform('0')
# print(train['category'])

print(train)
print(train_df)
# Out:
#                                              Contents  category  polarity  \
# 0                    my allergy killin my widdle eye          0  0.000000
# 1        well think i woke up today with pink eye smh         1 -0.100000
# 2   seriously fuck allergy my eye hurt and itch so...         0 -0.637500
# 3                               my eye itchin allergy         0  0.000000
# 4   november wa hand foot and mouth december is i ...         1 -0.362500
# 5                                  allergy ugh my eye         0  0.000000
# 6                                i have pink eye cool         1  0.125000
# 7                                 i have pink eye fml         1 -0.100000
# 8   know how to feel like a kid again get a case o...         1 -0.125000
# 9                    allergy seasonmy eye itch so bad         0 -0.700000
# 10                     i woke up with pink eye wtffff         1 -0.100000
# 11                  my allergy omg my eye i cant deal         0  0.000000
# 12  i have pink eye and a kid threw a pencil at me...         1 -0.100000
# 13                     pretty sure i have pink eye tf         1  0.216667
# 14  thanks timehop for reminding me that my kid ha...         1  0.087500
# 15                       ironic i would have pink eye         1  0.050000
# 16                          that kid gave me pink eye         1 -0.100000
# 17                           i have pink eye awesome          1  0.450000
# 18            these allergy man my eye itch like fuck         0 -0.400000
# 19  a child just farted longer than a macys commer...         1 -0.050000
# 20                 crap i forgot my eye drop  allergy         0 -0.775000
# 21        my eye is itching i need my allergy eyedrop         0  0.000000
# 22             stupid allergy my eye keep watering          0 -0.800000
# 23  im not used to having allergy my throat is dru...         0 -0.200000
# 24                          god my eye itch f allergy         0  0.000000
# 25                 my eye itch badly stinking allergy         0 -0.700000
# 26                          my poor baby ha pink eye          1 -0.416667
# 27                       pretty sure i have pink eye          1  0.216667
# 28                      my eye hurt screw you allergy         0  0.000000
# 29                              aahhh my eye  allergy         0  0.000000
# ..                                                ...       ...       ...
# 56                           my eye burnnnî† allergy         0  0.000000
# 57   i really hope my baby not catching the pink eye          1 -0.066667
# 58  my baby got allergy it eye water every time we...         0  0.000000
# 59  i think my allergy starting to kick in  my eye...         0  0.000000
# 60  i would like to thank the child at summer camp...         1 -0.100000
# 61  my poor little one now ha pink eyeif it not on...         1 -0.229167
# 62                       my eye itch damn you allergy         0  0.000000
# 63  2 baby home with pink eyeughthank you parent w...         1 -0.125000
# 64                                   i have pink eye          1  0.200000
# 65    my throat my eye my nose screw allergy hatethis         0  0.000000
# 66                     morning my kid ha pink eye yay         1 -0.100000
# 67      these allergy have my eye dry i need eye drop         0 -0.066667
# 68                      at home w baby he ha pink eye         1 -0.100000
# 69  tonight i have one sick kid and one kid with p...         1  0.079762
# 70   fuckkkkk these allergy im sneezing  my eye itch          0  0.000000
# 71                    i seriously have pink eye again         1 -0.216667
# 72  so i woke up with pink eye i think this mornin...         1  0.125000
# 73  went outside so my daughter could play nose it...         0  0.000000
# 74                               my nose  eye itching         0  0.000000
# 75  could you not give my kid high five when you h...         1  0.030000
# 76                          sike i have pink eye fml          1 -0.100000
# 77                  damn allergy shot now my eye itch         0  0.000000
# 78                 my eye wont stop watering allergy          0  0.000000
# 79                    my allergy got my eye puffy smh         0  0.000000
# 80  why every time black ppl have to take their ki...         1 -0.133333
# 81                my eye are itching freakin allergy          0  0.000000
# 82   haha i wish but not sure i could pas for a co...         0 -0.015625
# 83     my allergy have my eye itching something crazy         0 -0.600000
# 84  earlier this wk it wa both kid wpink eye today...         1  0.081250
# 85                my eye itching so bad  damn allergy         0 -0.700000
#
#     subjectivity  tweet_length  no_of_words
# 0       0.000000          37.0          7.0
# 1       0.300000          47.0         10.0
# 2       0.633333          57.0         11.0
# 3       0.000000          24.0          4.0
# 4       0.650000         126.0         23.0
# 5       0.000000          32.0          4.0
# 6       0.475000          22.0          5.0
# 7       0.300000          19.0          5.0
# 8       0.300000          63.0         15.0
# 9       0.666667          38.0          6.0
# 10      0.300000          30.0          7.0
# 11      0.000000          37.0          8.0
# 12      0.300000          65.0         14.0
# 13      0.729630          31.0          7.0
# 14      0.204167         100.0         19.0
# 15      0.600000          28.0          6.0
# 16      0.300000          25.0          6.0
# 17      0.650000          28.0          6.0
# 18      0.600000          45.0          8.0
# 19      0.233333          99.0         17.0
# 20      0.900000          40.0          8.0
# 21      0.000000          45.0          9.0
# 22      1.000000          43.0          7.0
# 23      0.800000          79.0         14.0
# 24      0.000000          28.0          6.0
# 25      0.666667          38.0          6.0
# 26      0.633333          28.0          7.0
# 27      0.729630          30.0          7.0
# 28      0.000000          34.0          6.0
# 29      0.000000          27.0          5.0
# ..           ...           ...          ...
# 56      0.000000          29.0          4.0
# 57      0.466667          50.0         11.0
# 58      0.050000          64.0         12.0
# 59      0.100000          76.0         16.0
# 60      0.300000          96.0         16.0
# 61      0.466667          88.0         15.0
# 62      0.000000          33.0          6.0
# 63      0.300000         135.0         22.0
# 64      0.650000          18.0          5.0
# 65      0.000000          54.0          9.0
# 66      0.300000          34.0          7.0
# 67      0.600000          49.0         10.0
# 68      0.300000          33.0          8.0
# 69      0.647619         126.0         26.0
# 70      0.000000          55.0         10.0
# 71      0.483333          33.0          6.0
# 72      0.475000          53.0         12.0
# 73      0.050000          82.0         14.0
# 74      0.000000          22.0          5.0
# 75      0.420000          67.0         14.0
# 76      0.300000          29.0          7.0
# 77      0.000000          37.0          7.0
# 78      0.000000          45.0          7.0
# 79      0.000000          34.0          7.0
# 80      0.366667         140.0         26.0
# 81      0.000000          40.0          7.0
# 82      0.597222         108.0         19.0
# 83      0.900000          49.0          8.0
# 84      0.518750         137.0         26.0
# 85      0.666667          40.0          8.0
#
# [86 rows x 6 columns]
#      allergy      baby       bad  breathe      camp      case     child  \
# 0   0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 2   0.183742  0.000000  0.415670      0.0  0.000000  0.000000  0.000000
# 3   0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 5   0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000      0.0  0.000000  0.638466  0.000000
# 9   0.317343  0.000000  0.717908      0.0  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 11  0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 18  0.241807  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.671585
# 20  0.355065  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 21  0.305968  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 22  0.421361  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 23  0.235254  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 24  0.455862  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 25  0.455862  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 26  0.000000  0.483859  0.000000      0.0  0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 28  0.262655  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 29  0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# ..       ...       ...       ...      ...       ...       ...       ...
# 56  0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 57  0.000000  0.833318  0.000000      0.0  0.000000  0.000000  0.000000
# 58  0.226496  0.407632  0.000000      0.0  0.000000  0.000000  0.000000
# 59  0.280495  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 60  0.000000  0.000000  0.000000      0.0  0.448907  0.000000  0.448907
# 61  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 62  0.317343  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 63  0.000000  0.356158  0.000000      0.0  0.000000  0.000000  0.000000
# 64  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 65  0.238328  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 66  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 67  0.253173  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 68  0.000000  0.483859  0.000000      0.0  0.000000  0.000000  0.000000
# 69  0.000000  0.000000  0.000000      0.0  0.000000  0.426879  0.000000
# 70  0.249838  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 71  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 72  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 73  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 74  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 75  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 76  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 77  0.317343  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 78  0.421361  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 79  0.293501  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 80  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 81  0.492753  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 82  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 83  0.492753  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 84  0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 85  0.263945  0.000000  0.597108      0.0  0.000000  0.000000  0.000000
#
#         cool      damn      drop     ...        tonight  viral        wa  \
# 0   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 1   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 2   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 3   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 4   0.000000  0.404066  0.000000     ...       0.000000    0.0  0.457589
# 5   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 6   0.906410  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 7   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 8   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 9   0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 10  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 11  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 12  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 13  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 14  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 15  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 16  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 17  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 18  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 19  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 20  0.000000  0.000000  0.909642     ...       0.000000    0.0  0.000000
# 21  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 22  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 23  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 24  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 25  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 26  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 27  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 28  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 29  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# ..       ...       ...       ...     ...            ...    ...       ...
# 56  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 57  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 58  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 59  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 60  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
# 61  0.000000  0.000000  0.000000     ...       0.000000    0.0  0.000000
#
# 63  0.000000  0.000000  0.000000 -0.125000      0.300000         135.0
# 64  0.000000  0.000000  0.000000  0.200000      0.650000          18.0
# 65  0.000000  0.000000  0.000000  0.000000      0.000000          54.0
# 66  0.000000  0.000000  0.000000 -0.100000      0.300000          34.0
# 67  0.000000  0.000000  0.000000 -0.066667      0.600000          49.0
# 68  0.000000  0.000000  0.000000 -0.100000      0.300000          33.0
# 69  0.000000  0.000000  0.000000  0.079762      0.647619         126.0
# 70  0.000000  0.000000  0.000000  0.000000      0.000000          55.0
# 71  0.000000  0.000000  0.000000 -0.216667      0.483333          33.0
# 72  0.000000  0.479354  0.000000  0.125000      0.475000          53.0
# 73  0.417548  0.000000  0.000000  0.000000      0.050000          82.0
# 74  0.000000  0.000000  0.000000  0.000000      0.000000          22.0
# 75  0.000000  0.000000  0.000000  0.030000      0.420000          67.0
# 76  0.000000  0.000000  0.000000 -0.100000      0.300000          29.0
# 77  0.000000  0.000000  0.000000  0.000000      0.000000          37.0
# 78  0.870055  0.000000  0.000000  0.000000      0.000000          45.0
# 79  0.000000  0.000000  0.000000  0.000000      0.000000          34.0
# 80  0.000000  0.000000  0.000000 -0.133333      0.366667         140.0
# 81  0.000000  0.000000  0.000000  0.000000      0.000000          40.0
# 82  0.000000  0.000000  0.000000 -0.015625      0.597222         108.0
# 83  0.000000  0.000000  0.000000 -0.600000      0.900000          49.0
# 84  0.000000  0.000000  0.000000  0.081250      0.518750         137.0
# 85  0.000000  0.000000  0.000000 -0.700000      0.666667          40.0
#
#     no_of_words
# 0           7.0
# 1          10.0
# 2          11.0
# 3           4.0
# 4          23.0
# 5           4.0
# 6           5.0
# 7           5.0
# 8          15.0
# 9           6.0
# 10          7.0
# 11          8.0
# 12         14.0
# 13          7.0
# 14         19.0
# 15          6.0
# 16          6.0
# 17          6.0
# 18          8.0
# 19         17.0
# 20          8.0
# 21          9.0
# 22          7.0
# 23         14.0
# 24          6.0
# 25          6.0
# 26          7.0
# 27          7.0
# 28          6.0
# 29          5.0
# ..          ...
# 56          4.0
# 57         11.0
# 58         12.0
# 59         16.0
# 60         16.0
# 61         15.0
# 62          6.0
# 63         22.0
# 64          5.0
# 65          9.0
# 66          7.0
# 67         10.0
# 68          8.0
# 69         26.0
# 70         10.0
# 71          6.0
# 72         12.0
# 73         14.0
# 74          5.0
# 75         14.0
# 76          7.0
# 77          7.0
# 78          7.0
# 79          7.0
# 80         26.0
# 81          7.0
# 82         19.0
# 83          8.0
# 84         26.0
# 85          8.0
#
# [86 rows x 57 columns]

# %%
### wrire in csv
dataframe = pd.DataFrame(train.Contents)
dataframe = dataframe.join(train_df)

classified = pd.DataFrame(train.category)
dataframe = dataframe.join(classified)

dataframe.to_csv("/Users/tejasvibelsare/Documents/complete_frame.csv", encoding='utf-8')
train_df.to_csv("/Users/tejasvibelsare/Documents/features.csv", encoding='utf-8')

# %%
train_df
# Out:
#      allergy      baby       bad  breathe      camp      case     child  \
# 0   0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 2   0.183742  0.000000  0.415670      0.0  0.000000  0.000000  0.000000
# 3   0.854767  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000      0.0  0.000000  0.000000  0.000000
#
# 82  0.000000  0.000000  0.000000 -0.015625      0.597222         108.0
# 83  0.000000  0.000000  0.000000 -0.600000      0.900000          49.0
# 84  0.000000  0.000000  0.000000  0.081250      0.518750         137.0
# 85  0.000000  0.000000  0.000000 -0.700000      0.666667          40.0
#
#     no_of_words
# 0           7.0
# 1          10.0
# 2          11.0
# 3           4.0
# 4          23.0
# 5           4.0
# 6           5.0
# 7           5.0
# 8          15.0
# 9           6.0
# 10          7.0
# 11          8.0
# 12         14.0
# 13          7.0
# 14         19.0
# 15          6.0
# 16          6.0
# 17          6.0
# 18          8.0
# 19         17.0
# 20          8.0
# 21          9.0
# 22          7.0
# 23         14.0
# 24          6.0
# 25          6.0
# 26          7.0
# 27          7.0
# 28          6.0
# 29          5.0
# ..          ...
# 56          4.0
# 57         11.0
# 58         12.0
# 59         16.0
# 60         16.0
# 61         15.0
# 62          6.0
# 63         22.0
# 64          5.0
# 65          9.0
# 66          7.0
# 67         10.0
# 68          8.0
# 69         26.0
# 70         10.0
# 71          6.0
# 72         12.0
# 73         14.0
# 74          5.0
# 75         14.0
# 76          7.0
# 77          7.0
# 78          7.0
# 79          7.0
# 80         26.0
# 81          7.0
# 82         19.0
# 83          8.0
# 84         26.0
# 85          8.0
#
# [86 rows x 57 columns]

# %%
# # print(tfidf)
# type(tfidf)
# # tfidf.toarray()
# print(X_train)

train['Contents'][8]
# Out:
# 'know how to feel like a kid again get a case of pink eye ack'

# %%
from sklearn.model_selection import KFold



kf = KFold(n_splits=5)
kf.get_n_splits(train)
# print(kf)
# tfidf = TfidfVectorizer(min_df=2,stop_words='english')
# tfidf_X_train = tfidf.fit_transform(train.Contents)


def performance_measures(model):
    acc = []
    pre = []
    rec = []
    f1 = []
    test = []
    predict = []
    probability = []
    fold = pd.DataFrame()

    conf_matrix = np.zeros((2,2))
    
    for train_index, test_index in kf.split(train_df):
#         print("TRAIN:", train_index, "TEST:", test_index)        #### printing indices of folds

        X_train, X_test = train_df.iloc[train_index], train_df.iloc[test_index]
        y_train, y_test = classified.iloc[train_index], classified.iloc[test_index]
        
        print(y_test.dtypes)
        model = model 
        model.fit(X_train,y_train)
        
#         # Calculate feature importances
#         importances = model.feature_importances_
#         print(importances)

        X_test.values
        y_pred = model.predict(X_test)
        probas = model.predict_proba(X_test)
        precision, recall, F1, _ = list(precision_recall_fscore_support(y_test,y_pred, beta=1.0, average="binary"))
        accuracy = accuracy_score(y_test,y_pred)
        matrix = confusion_matrix(y_test,y_pred)
        conf_matrix = conf_matrix.__add__(matrix)

        
        dataframe = pd.DataFrame(train.Contents)
        dataframe = dataframe.join(train_df)
        per_fold = pd.DataFrame(train.iloc[test_index])
        predicted_df = pd.DataFrame(y_pred.astype(int))
#         predicted_df = pd.DataFrame(y_pred)
        predicted_df.columns = ['predicted']
        predicted_df.reset_index(drop=True, inplace=True)
        per_fold.reset_index(drop=True, inplace=True)
        X_test.reset_index(drop=True, inplace=True)
#         per_fold = per_fold.join(predicted_df)
#         pd.merge(per_fold,predicted_df)
        per_fold = pd.concat([per_fold,predicted_df], axis=1)
#         per_fold = per_fold.join(X_test)
        per_fold = per_fold.merge(X_test)
        fold = fold.append(per_fold)
#         print(per_fold)
        
#         print(predicted_df)
        test.extend(y_test)
        predict.extend(y_pred)
#         y_pred.dtypes()
        probability.extend(probas[:, 1])
    
        acc.append(accuracy)
        pre.append(precision)
        rec.append(recall)
        f1.append(F1)
        
    print(model)
    print(conf_matrix)
    fold['match'] = fold.category.eq(fold.predicted)
    
    query = False
    wrong_predicted = pd.DataFrame(fold[fold['match'] == query])
    wrong_predicted.to_csv("/Users/tejasvibelsare/Documents/wrong_predicted_training.csv", encoding='utf-8')

#     print(fold.where(fold['match']== False))
    
#     print(fold)
    fold.to_csv("/Users/tejasvibelsare/Documents/fold_wise_comparison.csv", encoding='utf-8')
    
#     probas =  model.predict_proba(X_test)
    
#     plot_roc(test,probability)
    
    return test, predict, acc, pre, rec, f1
# Out:
# 5

# %%
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import svm

model_naive = GaussianNB()
# modelSVM = svm.SVC(kernel='linear',probability=True)

test, predict, acc, pre, rec, f1 = performance_measures(model_naive)
all_folds_performance = {'Accuracy':acc, 'Precision': pre, 'Recall':rec, 'F1': f1}
naive_model_perf = {'acc':np.mean(acc), 'pre':np.mean(pre),'rec':np.mean(rec),'f1':np.mean(f1)}
# Out:
# category    int64
# dtype: object
# category    int64
# dtype: object
# category    int64
# dtype: object
# category    int64
# dtype: object
# category    int64
# dtype: object
# GaussianNB(priors=None, var_smoothing=1e-09)
# [[40.  5.]
#  [ 2. 39.]]
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# #### tfidf vectorizer
# from sklearn.feature_extraction.text import TfidfVectorizer

# tfidf = TfidfVectorizer(min_df=2,stop_words='english')
# traintfidf = tfidf.fit_transform(train.Contents)
# traintfidf.ndim
# type(traintfidf)

# %%
# traintfidf.toarray()
# traintfidf.getnnz()
# traintfidf.shape

# %%
naive_model_perf
all_folds_performance
# Out:
# {'acc': 0.9183006535947712,
#  'pre': 0.8877777777777778,
#  'rec': 0.9547619047619047,
#  'f1': 0.9173174197215118}
# {'Accuracy': [0.9444444444444444,
#   1.0,
#   0.9411764705882353,
#   0.8823529411764706,
#   0.8235294117647058],
#  'Precision': [1.0, 1.0, 0.8888888888888888, 0.8, 0.75],
#  'Recall': [0.9166666666666666, 1.0, 1.0, 1.0, 0.8571428571428571],
#  'F1': [0.9565217391304348,
#   1.0,
#   0.9411764705882353,
#   0.888888888888889,
#   0.7999999999999999]}

# %%
classified.shape
train_df.shape
# Out:
# (86, 1)
# (86, 57)

# %%
def predict(model, X_gold, y_gold,X_predict, classified_by_crimson):
    
    
    model = model 
    model.fit(X_gold,y_gold)
#     X_predict.toarray()
    y_pred = model.predict(X_predict)
    y_predicted = pd.DataFrame(y_pred.astype(int))
    probas = model.predict_proba(X_gold)
    
#     print(type(classified_by_crimson))
#     print(type(y_pred))
    
#     print(classified_by_crimson)
#     print(y_pred)
#     print(classified_by_crimson.dtypes)
#     classified_by_crimson.value_counts()
#     y_predicted.value_counts()
    
    precision, recall, F1, _ = list(precision_recall_fscore_support(classified_by_crimson,y_predicted, beta=1.0, average="binary"))
    
    
    accuracy = accuracy_score(classified_by_crimson,y_predicted)
#     matrix = confusion_matrix(classified_by_crimson,y_pred)
#     conf_matrix = conf_matrix.__add__(matrix)

#     answer = pd.concat([classified_by_crimson,y_predicted], axis=1)
#     X_predict.reset_index(drop=True, inplace=True)
#     answer = answer.join(X_predict)
# #     answer = pd.concat([X_predict, answer], axis=1)
#     print(answer)
  
#     "There are %d births" % (births,)
    print("Precision : %.10f" % (precision,))
    print("Recall : %.10f" % (recall,))
    print("F1 : %.10f" % (F1,))
    print("Accuracy : %.10f" % (accuracy,))
    
    return y_predicted

# %%
file_path = "/Users/tejasvibelsare/Documents/Twitter10K.xlsx"
test = pd.read_excel(file_path, sheet_name='Sheet1',usecols = "B,L")
# test = pd.read_excel(file_path, sheet_name='Sheet1',usecols = "B")
# test

print(type(test))
test.reset_index(drop=True, inplace=True)
test = preprocess(test)

# print(test)

# train = pd.read_excel(file_path, sheet_name='Sheet1',usecols = "B,H")

testtfidf = tfidf.transform(test['Contents'].apply(lambda x: np.str_(x)))

print(type(testtfidf))
testtfidf = pd.DataFrame(testtfidf.toarray())

testtfidf.columns = tfidf.get_feature_names()

sentiment = pd.DataFrame(test[['polarity','subjectivity','tweet_length','no_of_words']])
# df1 = df[['a','b']]
testtfidf = pd.concat([testtfidf,sentiment], axis=1)

# testtfidf = tfidf.transform(test.Contents)
testtfidf.shape
# test_gold = pd.DataFrame(testtfidf.todense())
# test_gold.shape
# # test_gold.columns = test_gold.get_feature_names()

Mode_classified = test.loc[:, "classified"].mode() 
test = test.fillna({"classified":Mode_classified[0]})

classified_10K = test["classified"]
# classified_by_crimson = classified_by_crimson.dropna(how='all')


# classified = classified_by_crimson["classified"]
classified_10K.isnull().values.any()
# classified_10K.astype('int64')

# classified_10K.value_counts()

# classified_10K.to_csv("/Users/tejasvibelsare/Documents/error.csv", encoding='utf-8')

classified_by_crimson = pd.DataFrame(classified_10K)

classified_by_crimson.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'scipy.sparse.csr.csr_matrix'>
# (4800, 57)
# False
# (4800, 1)

# %%
print(test)
# Out:
#                                                Contents  classified  polarity  \
# 0     so im finally feeling better just have a bad c...         1.0 -0.060000
# 1                 i have pink eye in both eyesthis blow         1.0 -0.100000
# 2     some girl had pinkeye in my school today and w...         1.0 -0.358333
# 3     i bet people think im high but i actually just...         1.0 -0.185000
# 4      hahahahaha me too i got an mc hahaha saw the ...         0.0  0.200000
# 5            im pretty sure i have fucking pink eye fml         1.0  0.216667
# 6       i would not suggest getting pink eye cuz it ...         1.0 -0.550000
# 7     i watched the vlog where  got pink eye and now...         1.0 -0.100000
# 8                    i gots pink eye in both of my eye          1.0 -0.100000
# 9          i just had to put eye allergy drop in my eye         0.0  0.000000
# 10                                i have an eye allergy         0.0  0.000000
# 11    conjunctivitis in my eye    3\n\nfml worsttime...         1.0 -0.750000
# 12    i couldnt go to tennis tryout bc i have pink e...         1.0 -0.100000
# 13                                  i have pink eye ugh         1.0 -0.100000
# 14    5 ouch im trying to get ready for work but i h...         1.0 -0.077778
# 15                      oh my lord my eye itch  allergy         0.0  0.000000
# 16                     my mom mad assl she ha pink eye          1.0 -0.362500
# 17                 look like i have pink eye oh my fuck         1.0 -0.250000
# 18    going to the nurse tomorrow i think i have pin...         1.0 -0.100000
# 19    i step outside for 2 second and my eye itch li...         0.0 -0.300000
# 20                         my eye itch fuck you allergy         0.0 -0.400000
# 21                           he told me i have pink eye         1.0 -0.100000
# 22     i do have pink eye  im just hoping bowen does...         1.0 -0.156250
# 23                 i hate my allergy my eye itch so bad         0.0 -0.750000
# 24    coco crisp is out due to pink eye in both eye ...         1.0  0.008333
# 25    what a day been taking care of my dad he got p...         1.0 -0.100000
# 26    this eye allergy is getting on my nerve really...         0.0  0.200000
# 27    i had a runny nose and watery eye at work beca...         0.0 -0.162500
# 28    okay so ive got conjunctivitis it look like i ...         1.0  0.300000
# 29    i have conjunctivitis but cant afford eye drop...         1.0  0.000000
# ...                                                 ...         ...       ...
# 4770               my eye itch  i need allergy eye drop         0.0  0.000000
# 4771  i cant stop sneezing and itching my eye i hate...         0.0 -0.800000
# 4772                           i hate pink eye noschool         1.0 -0.450000
# 4773  eye watering itching nose running sneezing thr...         0.0 -0.800000
# 4774              i fucking hate pink eye sogross whyme         1.0 -0.450000
# 4775                               i hate pink eye wahh         1.0 -0.450000
# 4776         my nose and eye are fuckin itching allergy         0.0  0.000000
# 4777  these allergy bout to kick my as eye already i...         0.0  0.000000
# 4778                pretty sure i have fucking pink eye         1.0  0.216667
# 4779  gaaaahhhhhh my eye are itching nose is tingly ...         0.0  0.000000
# 4780                                i have pink eye ugh         1.0 -0.100000
# 4781  i hate my allergy puffy as eye always itching ...         0.0 -0.800000
# 4782               my allergy are bad eye hella itching         0.0 -0.700000
# 4783  i hate pink eye i hate pink eye i hate pink ey...         1.0 -0.450000
# 4784                       i hate pink eye seriouslybro         1.0 -0.450000
# 4785         my nose is running and my eye itch allergy         0.0  0.000000
# 4786                         ugh i hate having pink eye         1.0 -0.450000
# 4787                my allergy drawling eye all itching         0.0  0.000000
# 4788  since i lost my allergy pill my eye itch and b...         0.0  0.000000
# 4789                  i hate allergy my eye itch so bad         0.0 -0.937500
# 4790                    fuck allergy my eye itch so bad         0.0 -0.550000
# 4791                 my eye itch i hate allergy so much         0.0 -0.300000
# 4792                   pretty sure i have pink eye fuck         1.0  0.062500
# 4793                                i have pink eye ugh         1.0 -0.100000
# 4794         ugh i hate allergy my eye itch like crazy          0.0 -0.550000
# 4795                   stupid allergy make my eye itch          0.0 -1.000000
# 4796          my eye keep itching my allergy acting up          0.0  0.000000
# 4797                                ugh i have pink eye         1.0 -0.100000
# 4798                   nooooooo now my eye itch allergy         0.0  0.000000
# 4799              fuck these allergy my eye itch so bad         0.0 -0.700000
#
#       subjectivity  tweet_length  no_of_words
# 0         0.493333          98.0         21.0
# 1         0.300000          41.0          8.0
# 2         0.583333         110.0         21.0
# 3         0.485000          81.0         17.0
# 4         0.500000         108.0         18.0
# 5         0.729630          44.0          9.0
# 6         0.650000          75.0         13.0
# 7         0.300000         121.0         20.0
# 8         0.300000          48.0         11.0
# 9         0.000000          57.0         12.0
# 10        0.000000          21.0          5.0
# 11        1.000000          63.0          9.0
# 12        0.300000          76.0         15.0
# 13        0.300000          19.0          5.0
# 14        0.488889          95.0         17.0
# 15        0.000000          40.0          8.0
# 16        0.650000          35.0          9.0
# 17        0.450000          37.0          9.0
# 18        0.300000          55.0         11.0
# 19        0.475000          68.0         13.0
# 20        0.600000          35.0          6.0
# 21        0.300000          43.0          9.0
# 22        0.300000          77.0         14.0
# 23        0.783333          39.0          9.0
# 24        0.363889         114.0         22.0
# 25        0.300000         114.0         23.0
# 26        0.200000          55.0         10.0
# 27        0.700000         135.0         27.0
# 28        0.516667          73.0         13.0
# 29        0.000000          60.0          9.0
# ...            ...           ...          ...
# 4770      0.000000          40.0          9.0
# 4771      0.900000          65.0         13.0
# 4772      0.600000          28.0          5.0
# 4773      0.900000          87.0         11.0
# 4774      0.600000          39.0          7.0
# 4775      0.600000          22.0          5.0
# 4776      0.000000          46.0          8.0
# 4777      0.000000          57.0         10.0
# 4778      0.729630          35.0          7.0
# 4779      0.000000          65.0         10.0
# 4780      0.300000          21.0          5.0
# 4781      0.900000          75.0         14.0
# 4782      0.666667          40.0          7.0
# 4783      0.600000          81.0         17.0
# 4784      0.600000          29.0          5.0
# 4785      0.000000          46.0          9.0
# 4786      0.600000          26.0          6.0
# 4787      0.000000          37.0          6.0
# 4788      0.333333          63.0         12.0
# 4789      0.783333          38.0          8.0
# 4790      0.633333          33.0          7.0
# 4791      0.550000          37.0          8.0
# 4792      0.697222          34.0          7.0
# 4793      0.300000          21.0          5.0
# 4794      0.933333          49.0         10.0
# 4795      1.000000          40.0          7.0
# 4796      0.000000          54.0          9.0
# 4797      0.300000          19.0          5.0
# 4798      0.000000          37.0          6.0
# 4799      0.633333          43.0          8.0
#
# [4800 rows x 6 columns]

# %%
# np.isnan(train_df)
# np.isnan(classified)


classified = pd.DataFrame(classified)
# predicted_values = predict(modelSVM, train_df, classified, testtfidf, classified_by_crimson)
predicted_values = predict(model_naive, train_df, classified, testtfidf, classified_by_crimson)


predicted_values.columns = ['model_prediction']

print(type(testtfidf))

test_tfidf = testtfidf
# test_tfidf = pd.DataFrame(testtfidf.todense())
# test_tfidf.columns = tfidf.get_feature_names()

compare = pd.concat ([test,test_tfidf], axis=1)
compare = pd.concat([compare,predicted_values], axis=1) 

compare['match'] = compare.classified.eq(compare.model_prediction)
    
query = False
wrong_predicted = pd.DataFrame(compare[compare['match'] == query])
# predicted_df.reset_index(drop=True, inplace=True)
# per_fold.reset_index(drop=True, inplace=True)

compare.to_csv("/Users/tejasvibelsare/Documents/error.csv", encoding='utf-8')
wrong_predicted.to_csv("/Users/tejasvibelsare/Documents/model_wrong_predicted.csv", encoding='utf-8')



# train_df = pd.DataFrame(traintf.todense())
# train_df.columns = tfidf.get_feature_names()
# Out:
# Precision : 0.8185840708
# Recall : 0.8937198068
# F1 : 0.8545034642
# Accuracy : 0.9868750000
# <class 'pandas.core.frame.DataFrame'>
# /anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
